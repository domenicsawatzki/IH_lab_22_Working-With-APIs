# %% [markdown]
# ### Load libraries

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

import pandas as pd
from pandas import json_normalize

from tqdm import tqdm
import time 
import json 

from random import randint
import time 

import pickle

# %% [markdown]
# ### Connect with Spotify API using spotipy library

# %%
def connect_spotipy():
    with open("secrets.txt","r") as f:
        string = f.read()
    
    secrets_dict={}
    
    for line in string.split('\n'):
        if len(line) > 0:
            #print(line.split(':'))
            secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()
            

    #Initialize SpotiPy with user credentials
    sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                            client_secret=secrets_dict['clientsecret']))
    return sp

# %%
sp = connect_spotipy()

# %% [markdown]
# ### Get spotify playlists by categories

# %%
def get_playlists_by_categories():
    
    # get categories 
    categories = sp.categories(limit = 50)['categories']['items']
    

    # get playlist by categories
    top_playlists_by_genre = {}
    for category in tqdm(categories, desc = 'Fetching top playlists for each category.'):
        try:
            top_playlists_by_genre[category['name']] = sp.category_playlists(category_id=category['id'], limit=15)['playlists']['items']
            time.sleep(0.5)  # Introducing a half-second delay between each call
        except spotipy.SpotifyException as e:
            print(f"Error fetching playlists for category {category['name']}: {e}")
    all_playlist_ids = [playlist['id'] for genre in top_playlists_by_genre.values() for playlist in genre]
    
    return all_playlist_ids

# %%
top_playlist_ids = get_playlists_by_categories()

# %% [markdown]
# ### Get tracks from all playlists
# - get all tracks
# - remove duplicates

# %%
def get_all_tracks(playlist_ids):
    all_tracks = []
    
    # go trough all playlists and get tracks
    for playlist_id in tqdm(playlist_ids):
        tracks = get_tracks_from_playlist(playlist_id)
        all_tracks.extend(tracks) # add tracks to total list 

    final_tracks = json_normalize(all_tracks) # json normalize data 
    final_tracks.dropna(subset='track.artists', inplace = True) # drop null values
    final_tracks = final_tracks.drop_duplicates(subset=["track.id"]) # drop duplicates
    final_tracks ['artist_dict'] = final_tracks ['track.artists'].apply(list_to_dict)
    
    final_tracks.to_pickle('temp_data/tracks_from_playlists.pkl')
    return 

def get_tracks_from_playlist(playlist_id):
    offset = 0
    tracks = []
    while True:
        response = sp.playlist_tracks(playlist_id, offset=offset)
        tracks.extend(response['items'])
        if response['next'] is None:
            break
        offset += 100
        time.sleep(0.5)
    return tracks

def list_to_dict(x):
    return {i: x[i] for i in range(len(x))}

# %%
get_all_tracks(top_playlist_ids)

# %% [markdown]
# ### Delete unnecessary columns

# %%
tracks = pd.read_pickle('temp_data/tracks_from_playlists.pkl')

# %%
tracks.head(2).T

# %%
columns_to_keep = ['track.id', 'track.name', 'track.external_urls.spotify','artist_dict', 'track.album.id', 'track.album.name', 'track.album.images', 'track.album.release_date' ,'track.popularity']
tracks = tracks[columns_to_keep]

display(tracks.head(5))
tracks.to_pickle('temp_data/final_tracks.pkl')

# %% [markdown]
# ### Extract artists to get further songs

# %%
tracks = pd.read_pickle('temp_data/final_tracks.pkl')

# %%
def expand_list_dict(row):
    df = pd.DataFrame.from_dict(row['artist_dict'], orient='index')
    df['song_id'] = row['track.id']
    return df

# %%
tqdm.pandas()
tracks['artists_dfs'] = tracks.progress_apply(expand_list_dict, axis=1)

# %%
# create new dataframe with columns to keep
artist_df = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri'])

# extract data for each artist df
for val in tqdm(tracks['artists_dfs']):
    #display(val)
    artist_df = pd.concat([artist_df, val], axis=0)

# %%
artist_df.drop_duplicates(subset='id', inplace=True)
artist_df.to_pickle("temp_data/artist_df.pkl")

# %% [markdown]
# ### Get top 10 songs from each artist

# %%
artist_df = pd.read_pickle('temp_data/artist_df.pkl')

# %%
# extract artist IDs
artist_list = artist_df['id'].to_list()

# %%
# split artist list into smaller slices (50) for separate APIs calls

artist_dict = {}
slice_size = 50

for i in range(0, len(artist_list), slice_size):
    temp = artist_list[i:i+slice_size]
    artist_dict[i] = temp

# %%
# print(f"Search top songs for artist_list number = {}")

top10_songs = []
counter = 0

for key in artist_dict:
    # print(artist_dict[key])
    counter += 1
    print(f'Start finding top tracks: {counter}/{len(artist_dict)} - current len {len(top10_songs)}')
    for item in tqdm(artist_dict[key]):
        try:
            response = sp.artist_top_tracks(item)
            time.sleep(randint(1,3000)/1000)
            top10_songs = top10_songs + response["tracks"]
        except spotipy.SpotifyException as e:
            print(f"Error fetching songs for artist id {item}: {e}")
    
    with open('temp_data/top10_tracks.json', 'w') as file:
        json.dump(top10_songs, file)

# %% [markdown]
# ### import new songs and combine with old track dataset

# %%
final_tracks = pd.read_pickle('temp_data/final_tracks.pkl')
final_tracks.head(2).T

# %%
with open('temp_data/top10_tracks.json', 'r') as file:
    song_update = json.load(file)

# %%
update = json_normalize(song_update)

# %% [markdown]
# ### Get Audio Features and add to current dataframe

# %%
final_tracks = pd.read_pickle('temp_data/final_tracks.pkl')
final_tracks.head(2).T

# %%
def get_audio_features(df):

    chunks = [(i, i+100) for i in range(0, len(df), 100)]
    audio_features_list = []

    for chunk in tqdm(chunks):
        id_list100 = df['track.id'][chunk[0]:chunk[1]]
        audio_features_list = audio_features_list + sp.audio_features(id_list100)
        time.sleep(randint(1,3000)/1000)
    len(audio_features_list)
    audio_feature_df = json_normalize(audio_features_list )
    
    return audio_feature_df

# %%
audio_features =  get_audio_features(final_tracks)

# %%
audio_features.to_pickle('temp_data/audio_features_final_tracks.pkl')

# %%
with open ('temp_data/audio_features_final_tracks.pkl', 'br') as file:
    audio_features = pd.read_pickle(file)

with open ('temp_data/final_tracks.pkl', 'br') as file:
    final_tracks = pd.read_pickle(file)

final_tracks = final_tracks.reset_index(drop=True)
 
dataset_for_model = pd.concat([final_tracks, audio_features], axis = 1)
dataset_for_model

# %% [markdown]
# ### Extract the artists dict

# %%
def expand_list_dict(row):
    df = pd.DataFrame.from_dict(row['artist_dict'], orient='index')
    df['song_id'] = row['id']
    return df

dataset_for_model['artists_dfs'] = dataset_for_model.apply(expand_list_dict, axis=1)
type(dataset_for_model['artists_dfs'][0])
# Out:
# pandas.core.frame.DataFrame

# %%
dataset_for_model.head(2).T
# Out:
#                                                                              0  \
# track.id                                                31nfdEooLEq7dn3UMcIeB5
# track.name                                    Vois sur ton chemin - Techno Mix
# track.external_urls.spotify  https://open.spotify.com/track/31nfdEooLEq7dn3...
# artist_dict                  {0: {'external_urls': {'spotify': 'https://ope...
# track.album.id                                          79Cyc8GRWnLyjdJSMyJ0dB
# track.album.name                              Vois sur ton chemin (Techno Mix)
# track.album.images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.release_date                                            2023-08-04
# track.popularity                                                          85.0
# danceability                                                             0.634
# energy                                                                   0.824
# key                                                                        2.0
# loudness                                                                -3.394
# mode                                                                       0.0
# speechiness                                                              0.047
# acousticness                                                            0.0908
# instrumentalness                                                        0.0711
# liveness                                                                 0.119
# valence                                                                  0.371
# tempo                                                                  137.959
# type                                                            audio_features
# id                                                      31nfdEooLEq7dn3UMcIeB5
# uri                                       spotify:track:31nfdEooLEq7dn3UMcIeB5
# track_href                   https://api.spotify.com/v1/tracks/31nfdEooLEq7...
# analysis_url                 https://api.spotify.com/v1/audio-analysis/31nf...
# duration_ms                                                           178156.0
# time_signature                                                             4.0
# artists_dfs                                                         externa...
#
#                                                                              1
# track.id                                                0gMTEHzNIyvxikxyUFFJxO
# track.name                                                          Summertime
# track.external_urls.spotify  https://open.spotify.com/track/0gMTEHzNIyvxikx...
# artist_dict                  {0: {'external_urls': {'spotify': 'https://ope...
# track.album.id                                          3d5e4tp3t5zTGu44NM88LQ
# track.album.name                                                    Summertime
# track.album.images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.release_date                                            2023-08-10
# track.popularity                                                          81.0
# danceability                                                             0.756
# energy                                                                   0.647
# key                                                                        6.0
# loudness                                                                -5.488
# mode                                                                       0.0
# speechiness                                                              0.159
# acousticness                                                             0.279
# instrumentalness                                                      0.000005
# liveness                                                                 0.102
# valence                                                                  0.464
# tempo                                                                  134.995
# type                                                            audio_features
# id                                                      0gMTEHzNIyvxikxyUFFJxO
# uri                                       spotify:track:0gMTEHzNIyvxikxyUFFJxO
# track_href                   https://api.spotify.com/v1/tracks/0gMTEHzNIyvx...
# analysis_url                 https://api.spotify.com/v1/audio-analysis/0gMT...
# duration_ms                                                           195466.0
# time_signature                                                             4.0
# artists_dfs                                                         externa...

# %%
artist_df = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri', 'song_id'])
for val in tqdm(dataset_for_model['artists_dfs']):
    #display(val)
    artist_df = pd.concat([artist_df, val], axis=0)
    
artist_df
# Out:
#  85%|███████████████████████████████████████████████████████████████▋           | 39017/45957 [02:15<00:24, 288.43it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\Domen\IronHack\01_labs\IH_lab_22_Working-With-APIs\lab-song_recommender\main.ipynb Cell 40 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y103sZmlsZQ%3D%3D?line=0'>1</a> artist_df = pd.DataFrame(columns=['external_urls', 'href', 'id', 'name', 'type', 'uri', 'song_id'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y103sZmlsZQ%3D%3D?line=1'>2</a> for val in tqdm(dataset_for_model['artists_dfs']):
#       <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y103sZmlsZQ%3D%3D?line=2'>3</a>     #display(val)
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y103sZmlsZQ%3D%3D?line=3'>4</a>     artist_df = pd.concat([artist_df, val], axis=0)
#       <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y103sZmlsZQ%3D%3D?line=5'>6</a> artist_df
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:368, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     146 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     147 def concat(
#     148     objs: Iterable[NDFrame] | Mapping[HashableT, NDFrame],
#    (...)
#     157     copy: bool = True,
#     158 ) -> DataFrame | Series:
#     159     """
#     160     Concatenate pandas objects along a particular axis.
#     161
#    (...)
#     366     1   3   4
#     367     """
# --> 368     op = _Concatenator(
#     369         objs,
#     370         axis=axis,
#     371         ignore_index=ignore_index,
#     372         join=join,
#     373         keys=keys,
#     374         levels=levels,
#     375         names=names,
#     376         verify_integrity=verify_integrity,
#     377         copy=copy,
#     378         sort=sort,
#     379     )
#     381     return op.get_result()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:563, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     560 self.verify_integrity = verify_integrity
#     561 self.copy = copy
# --> 563 self.new_axes = self._get_new_axes()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:633, in _Concatenator._get_new_axes(self)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
# --> 633     return [
#     634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:634, in <listcomp>(.0)
#     631 def _get_new_axes(self) -> list[Index]:
#     632     ndim = self._get_result_dim()
#     633     return [
# --> 634         self._get_concat_axis if i == self.bm_axis else self._get_comb_axis(i)
#     635         for i in range(ndim)
#     636     ]
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:691, in _Concatenator._get_concat_axis(self)
#     689     if self.levels is not None:
#     690         raise ValueError("levels supported only when keys is not None")
# --> 691     concat_axis = _concat_indexes(indexes)
#     692 else:
#     693     concat_axis = _make_concat_multiindex(
#     694         indexes, self.keys, self.levels, self.names
#     695     )
#
# File ~\anaconda3\lib\site-packages\pandas\core\reshape\concat.py:709, in _concat_indexes(indexes)
#     708 def _concat_indexes(indexes) -> Index:
# --> 709     return indexes[0].append(indexes[1:])
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5405, in Index.append(self, other)
#    5402 names = {obj.name for obj in to_concat}
#    5403 name = None if len(names) > 1 else self.name
# -> 5405 return self._concat(to_concat, name)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5413, in Index._concat(self, to_concat, name)
#    5408 """
#    5409 Concatenate multiple Index objects.
#    5410 """
#    5411 to_concat_vals = [x._values for x in to_concat]
# -> 5413 result = concat_compat(to_concat_vals)
#    5415 is_numeric = result.dtype.kind in ["i", "u", "f"]
#    5416 if self._is_backward_compat_public_numeric_index and is_numeric:
#
# File ~\anaconda3\lib\site-packages\pandas\core\dtypes\concat.py:151, in concat_compat(to_concat, axis, ea_compat_axis)
#     148             to_concat = [x.astype("object") for x in to_concat]
#     149             kinds = {"o"}
# --> 151 result = np.concatenate(to_concat, axis=axis)
#     152 if "b" in kinds and result.dtype.kind in ["i", "u", "f"]:
#     153     # GH#39817
#     154     warnings.warn(
#     155         "Behavior when concatenating bool-dtype and numeric-dtype arrays is "
#     156         "deprecated; in a future version these will cast to object dtype "
#    (...)
#     160         stacklevel=find_stack_level(),
#     161     )
#
# File <__array_function__ internals>:180, in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
final_tracks_artist_split = pd.merge(left=dataset_for_model,
                    right=artist_df,
                    how='inner',
                    left_on='track.id',
                    right_on='song_id')

final_tracks_artist_split.to_pickle('temp_data/final_tracks_artist_split.pkl')

# %%
final_tracks_artist_split
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\Domen\IronHack\01_labs\IH_lab_22_Working-With-APIs\lab-song_recommender\main.ipynb Cell 42 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Domen/IronHack/01_labs/IH_lab_22_Working-With-APIs/lab-song_recommender/main.ipynb#Y112sZmlsZQ%3D%3D?line=0'>1</a> final_tracks_artist_split
#
# NameError: name 'final_tracks_artist_split' is not defined

# %% [markdown]
# ### Get further information about artist to create improved clusters

# %%
artist_df = pd.read_pickle('temp_data/artist_df.pkl')

# extract artist IDs
artist_list = artist_df['id'].to_list()

# split artist list into smaller slices (50) for separate APIs calls

artist_dict = {}
slice_size = 50

for i in range(0, len(artist_list), slice_size):
    temp = artist_list[i:i+slice_size]
    artist_dict[i] = temp

# %%
from random import randint
import time 

artist_genre = []

for key in tqdm(artist_dict):
    try:
        response = sp.artists(artist_dict[key])
        time.sleep(randint(1,3000)/1000)
        artist_genre = artist_genre + response["artists"]
    except spotipy.SpotifyException as e:
        print(f"Error fetching genre for artist{artist}: {e}")

# %%
with open('temp_data/artist_information.pkl', 'wb') as file:
    pickle.dump(artist_genre, file)

# %%
with open('temp_data/artist_information.pkl', 'rb') as file:
    artist_inf = pickle.load(file)
    
with open('temp_data/final_tracks_artist_split.pkl', 'rb') as file:
    final_tracks = pickle.load(file)

# %%
final_tracks.head(2).T
# Out:
#                                                                              0  \
# track.id                                                31nfdEooLEq7dn3UMcIeB5
# track.name                                    Vois sur ton chemin - Techno Mix
# track.external_urls.spotify  https://open.spotify.com/track/31nfdEooLEq7dn3...
# artist_dict                  {0: {'external_urls': {'spotify': 'https://ope...
# track.album.id                                          79Cyc8GRWnLyjdJSMyJ0dB
# track.album.name                              Vois sur ton chemin (Techno Mix)
# track.album.images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.release_date                                            2023-08-04
# track.popularity                                                          85.0
# danceability                                                             0.634
# energy                                                                   0.824
# key                                                                        2.0
# loudness                                                                -3.394
# mode                                                                       0.0
# speechiness                                                              0.047
# acousticness                                                            0.0908
# instrumentalness                                                        0.0711
# liveness                                                                 0.119
# valence                                                                  0.371
# tempo                                                                  137.959
# type_x                                                          audio_features
# id_x                                                    31nfdEooLEq7dn3UMcIeB5
# uri_x                                     spotify:track:31nfdEooLEq7dn3UMcIeB5
# track_href                   https://api.spotify.com/v1/tracks/31nfdEooLEq7...
# analysis_url                 https://api.spotify.com/v1/audio-analysis/31nf...
# duration_ms                                                           178156.0
# time_signature                                                             4.0
# artists_dfs                                                         externa...
# external_urls                {'spotify': 'https://open.spotify.com/artist/1...
# href                         https://api.spotify.com/v1/artists/1r43wW70tnG...
# id_y                                                    1r43wW70tnGUauQYvY5w48
# name                                                                   BENNETT
# type_y                                                                  artist
# uri_y                                    spotify:artist:1r43wW70tnGUauQYvY5w48
# song_id                                                 31nfdEooLEq7dn3UMcIeB5
#
#                                                                              1
# track.id                                                0gMTEHzNIyvxikxyUFFJxO
# track.name                                                          Summertime
# track.external_urls.spotify  https://open.spotify.com/track/0gMTEHzNIyvxikx...
# artist_dict                  {0: {'external_urls': {'spotify': 'https://ope...
# track.album.id                                          3d5e4tp3t5zTGu44NM88LQ
# track.album.name                                                    Summertime
# track.album.images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# track.album.release_date                                            2023-08-10
# track.popularity                                                          81.0
# danceability                                                             0.756
# energy                                                                   0.647
# key                                                                        6.0
# loudness                                                                -5.488
# mode                                                                       0.0
# speechiness                                                              0.159
# acousticness                                                             0.279
# instrumentalness                                                      0.000005
# liveness                                                                 0.102
# valence                                                                  0.464
# tempo                                                                  134.995
# type_x                                                          audio_features
# id_x                                                    0gMTEHzNIyvxikxyUFFJxO
# uri_x                                     spotify:track:0gMTEHzNIyvxikxyUFFJxO
# track_href                   https://api.spotify.com/v1/tracks/0gMTEHzNIyvx...
# analysis_url                 https://api.spotify.com/v1/audio-analysis/0gMT...
# duration_ms                                                           195466.0
# time_signature                                                             4.0
# artists_dfs                                                         externa...
# external_urls                {'spotify': 'https://open.spotify.com/artist/4...
# href                         https://api.spotify.com/v1/artists/4lDiJcOJ2GL...
# id_y                                                    4lDiJcOJ2GLCK6p9q5BgfK
# name                                                                  Kontra K
# type_y                                                                  artist
# uri_y                                    spotify:artist:4lDiJcOJ2GLCK6p9q5BgfK
# song_id                                                 0gMTEHzNIyvxikxyUFFJxO

# %%
artist_df = json_normalize(artist_inf)

# %%
columns_to_keep = ['id', 'images', 'name','popularity','external_urls.spotify','followers.total']
rename_columns = ['artist_id', 'artist_images', 'artist_name','artist_popularity','artist_link','artist_follower']
artist_df = artist_df[columns_to_keep]
artist_df.columns = rename_columns

# %%
artist_df
# Out:
#                     artist_id  \
# 0      1r43wW70tnGUauQYvY5w48
# 1      4lDiJcOJ2GLCK6p9q5BgfK
# 2      00FQb4jTyendYWaN8pK0wa
# 3      5cj0lLjcoR7YOSnhnX0Po5
# 4      2HIP5sNZWkrPgSBWRk8XpA
# ...                       ...
# 30237  26F0RxUxwCswnFxX3gecaD
# 30238  3sp7NtPgyjKKqYobNw8q6B
# 30239  2424G4yH7tJBPlbAoiVmc3
# 30240  4m6Gg5tLbuoiMNnEFOgtcK
# 30241  6IDvorIo7wSVdLDIUUvQMR
#
#                                            artist_images  \
# 0      [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 1      [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 2      [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 3      [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 4      [{'height': 640, 'url': 'https://i.scdn.co/ima...
# ...                                                  ...
# 30237  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30238                                                 []
# 30239  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30240  [{'height': 640, 'url': 'https://i.scdn.co/ima...
# 30241  [{'height': 640, 'url': 'https://i.scdn.co/ima...
#
#                          artist_name  artist_popularity  \
# 0                            BENNETT                 63
# 1                           Kontra K                 70
# 2                       Lana Del Rey                 89
# 3                           Doja Cat                 86
# 4                               SIRA                 68
# ...                              ...                ...
# 30237  Global Publishers Canada Inc.                 13
# 30238      Complete Language Lessons                  0
# 30239          Penton Overseas, Inc.                 14
# 30240                 Stephane Husar                  6
# 30241                     Qaïs Saadi                  2
#
#                                              artist_link  artist_follower
# 0      https://open.spotify.com/artist/1r43wW70tnGUau...            32511
# 1      https://open.spotify.com/artist/4lDiJcOJ2GLCK6...          2209647
# 2      https://open.spotify.com/artist/00FQb4jTyendYW...         27641500
# 3      https://open.spotify.com/artist/5cj0lLjcoR7YOS...         26209652
# 4      https://open.spotify.com/artist/2HIP5sNZWkrPgS...            17945
# ...                                                  ...              ...
# 30237  https://open.spotify.com/artist/26F0RxUxwCswnF...             5098
# 30238  https://open.spotify.com/artist/3sp7NtPgyjKKqY...             2914
# 30239  https://open.spotify.com/artist/2424G4yH7tJBPl...             5057
# 30240  https://open.spotify.com/artist/4m6Gg5tLbuoiMN...              553
# 30241  https://open.spotify.com/artist/6IDvorIo7wSVdL...               29
#
# [30242 rows x 6 columns]

# %%
final_tracks_model = pd.merge(left=final_tracks,
                    right=artist_df,
                    how='inner',
                    left_on='id_y',
                    right_on='artist_id')
final_tracks_model.to_pickle('temp_data/model_data_uncleaned.pkl')

# %%
final_tracks_model.to_pickle('temp_data/raw_model_tracks.pkl')
