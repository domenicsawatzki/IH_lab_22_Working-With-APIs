# %% [markdown]
# # API wrappers - Create your collection of songs & audio features
# ## Instructions
#
# To move forward with the project, you need to create a collection of songs with their audio features - as large as possible!
#
# These are the songs that we will cluster. And, later, when the user inputs a song, we will find the cluster to which the song belongs and recommend a song from the same cluster. The more songs you have, the more accurate and diverse recommendations you'll be able to give. Although... you might want to make sure the collected songs are "curated" in a certain way. Try to find playlists of songs that are diverse, but also that meet certain standards.
#
# The process of sending hundreds or thousands of requests can take some time - it's normal if you have to wait a few minutes (or, if you're ambitious, even hours) to get all the data you need.
#
# An idea for collecting as many songs as possible is to start with all the songs of a big, diverse playlist and then go to every artist present in the playlist and grab every song of every album of that artist. The amount of songs you'll be collecting per playlist will grow exponentially!

# %%
import pandas as pd
from pandas import json_normalize

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

# %%
secrets_file = open("secrets.txt","r")
string = secrets_file.read()

# %%
secrets_dict={}
for line in string.split('\n'):
    if len(line) > 0:
        #print(line.split(':'))
        secrets_dict[line.split(':')[0]]=line.split(':')[1].strip()

# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=secrets_dict['clientid'],
                                                           client_secret=secrets_dict['clientsecret']))

# %%
playlist = sp.user_playlist_tracks("spotify", "1hMzceeWw7QiI6vaBkcEJO")

# %%
# this one is biiiig!
playlist["total"]
# Out:
# 10000

# %%
len(playlist["items"])
# Out:
# 100

# %%
def get_categories():
    return sp.categories(limit = 50)['categories']['items'] #getting the categories

# %%
categories = get_categories() # store categories in a list of dictionaries
len(categories)
# Out:
# 47

# %%
for i in range(len(categories)):
    print(f"{i}: {categories[i]['id']}")
# Out:
# 0: toplists
# 1: 0JQ5DAqbMKFEC4WFtoNRpw
# 2: 0JQ5DAqbMKFQ00XGBls6ym
# 3: 0JQ5DAqbMKFzHmL4tf05da
# 4: 0JQ5DAqbMKFHOzuVTgTizF
# 5: 0JQ5DAqbMKFDXXwE9BDJAr
# 6: 0JQ5DAqbMKFFzDl7qN9Apr
# 7: 0JQ5DAqbMKFOOxftoKZxod
# 8: 0JQ5DAqbMKFImHYGo3eTSg
# 9: 0JQ5DAqbMKFPw634sFwguI
# 10: 0JQ5DAqbMKFA6SOHvT3gck
# 11: 0JQ5DAqbMKFIRybaNTYXXy
# 12: 0JQ5DAqbMKFCuoRTxhYWow
# 13: 0JQ5DAqbMKFAXlCG6QvYQ4
# 14: 0JQ5DAqbMKFCWjUTdzaG0e
# 15: 0JQ5DAqbMKFFtlLYUHv8bT
# 16: 0JQ5DAqbMKFIVNxQgRNSg0
# 17: 0JQ5DAqbMKFDkd668ypn6O
# 18: 0JQ5DAqbMKFx0uLQR2okcc
# 19: 0JQ5DAqbMKFFoimhOqWzLB
# 20: 0JQ5DAqbMKFEZPnFQSFB1T
# 21: 0JQ5DAqbMKFJKoGyUMo2hE
# 22: 0JQ5DAqbMKFCbimwdOYlsl
# 23: 0JQ5DAqbMKFF9bY76LXmfI
# 24: 0JQ5DAqbMKFAUsdyVjCQuL
# 25: 0JQ5DAqbMKFPrEiAOxgac3
# 26: 0JQ5DAqbMKFRY5ok2pxXJ0
# 27: 0JQ5DAqbMKFKLfwjuJMoNC
# 28: 0JQ5DAqbMKFLb2EqgLtpjC
# 29: 0JQ5DAqbMKFGvOw3O4nLAf
# 30: 0JQ5DAqbMKFEOEBCABAxo9
# 31: 0JQ5DAqbMKFAJ5xb0fwo9m
# 32: 0JQ5DAqbMKFIpEuaCnimBj
# 33: 0JQ5DAqbMKFAjfauKLOZiv
# 34: 0JQ5DAqbMKFObNLOHydSW8
# 35: 0JQ5DAqbMKFxXaXKP7zcDp
# 36: 0JQ5DAqbMKFCfObibaOZbv
# 37: 0JQ5DAqbMKFAQy4HL4XU2D
# 38: 0JQ5DAqbMKFRieVZLLoo9m
# 39: 0JQ5DAqbMKFLjmiZRss79w
# 40: 0JQ5DAqbMKFRKBHIxJ5hMm
# 41: 0JQ5DAqbMKFQIL0AXnG5AK
# 42: 0JQ5DAqbMKFQ1UFISXj59F
# 43: funk
# 44: 0JQ5DAqbMKFy78wprEpAjl
# 45: 0JQ5DAqbMKFQiK2EHwyjcU
# 46: word

# %%
def get_top_playlists_by_genre(genre_id): 
    return sp.category_playlists(category_id=genre_id, limit=15)['playlists']['items']

# %%
from tqdm import tqdm
import time 

top_playlists_by_genre = {}
for category in tqdm(categories, desc = 'Fetching top playlists for each category.'):
    try:
        top_playlists_by_genre[category['name']] = get_top_playlists_by_genre(category['id'])
        time.sleep(0.5)  # Introducing a half-second delay between each call
    except spotipy.SpotifyException as e:
        print(f"Error fetching playlists for category {category['name']}: {e}")
# Out:
# Fetching top playlists for each category.:  91%|███████████████████████████████████▋   | 43/47 [00:27<00:02,  1.61it/s]HTTP Error for GET to https://api.spotify.com/v1/browse/categories/funk/playlists with Params: {'country': None, 'limit': 15, 'offset': 0} returned 404 due to Specified id doesn't exist
# Error fetching playlists for category Funk: http status: 404, code:-1 - https://api.spotify.com/v1/browse/categories/funk/playlists?limit=15&offset=0:
#  Specified id doesn't exist, reason: None
# Fetching top playlists for each category.: 100%|███████████████████████████████████████| 47/47 [00:29<00:00,  1.58it/s]

# %%
len(top_playlists_by_genre)

list = top_playlists_by_genre.keys()
list
# Out:
# dict_keys(['Top Lists', 'Pop', 'Hip-Hop', 'Mood', 'Dance/Electronic', 'Rock', 'Chill', 'RADAR', 'Fresh Finds', 'EQUAL', 'Party', 'In the car', 'Sleep', 'Workout', 'Indie', 'Alternative', 'Decades', 'Metal', 'At Home', 'Kids & Family', 'R&B', 'Reggae', 'Focus', 'Frequency', 'Romance', 'Classical', 'Cooking & Dining', 'Country', 'Wellness', 'K-Pop', 'Netflix', 'Jazz', 'Soul', 'Punk', 'Caribbean', 'Latin', 'Gaming', 'Travel', 'Instrumental', 'Ambient', 'Tastemakers', 'Trending', 'Arab', 'Folk & Acoustic', 'Blues', 'Word'])

# %%
for i in list:
    print(f"{i} ({len(top_playlists_by_genre[i])})")
    if top_playlists_by_genre[i] is not None:
        for e in range(len(top_playlists_by_genre[i])):
            if top_playlists_by_genre[i][e] is not None:
                print(f""" -{top_playlists_by_genre[i][e]['name']}""")
# Out:
# Top Lists (13)
#  -Hot Hits Deutschland
#  -Main Stage
#  -Modus Mio
#  -New Music Friday Deutschland
#  -mint
#  -RapCaviar
#  -Rock This
#  -Are & Be
#  -Fresh Finds
#  -Top 50 – Deutschland
#  -Top 50 – Global
#  -Viral 50 – Global
#  -Viral 50 – Deutschland
# Pop (15)
#  -Hot Pink
#  -Barbie Official Playlist
#  -Throwback Jams
#  -Pop Remix
#  -Chill Pop
#  -Romcom
#  -after school club 🪄
#  -y2k
#  -Summer Pop
#  -Retro Prom
#  -Disco Decadence
#  -2000s Pop
#  -hot girl walk
#  -neon cowgirl
#  -DISCOLAND
# Hip-Hop (15)
#  -Modus Mio
#  -Deutschrap Brandneu
#  -Shisha Club
#  -Deutschrap Royal
#  -DREAMCHASERS
#  -Rap in deep
#  -Rap oder Liebe
#  -Deutschrap Untergrund
#  -Deutschrap Party
#  -Deutschrap Asphalt
#  -Deutschrap: Die Klassiker
#  -Deutschrap Primetime
#  -Straßenrap Classics
#  -Deutschrap: Die Anfänge
#  -word!
# Mood (15)
#  -me right now
#  -Stimmungsmacher
#  -Herbst Chillout
#  -Happy Dance
#  -Herbstgefühle
#  -Top of the Morning
#  -Feelgood Indie
#  -Happy Hits!
#  -Kaffeehausmusik
#  -Feelgood Pop
#  -Happy Beats
#  -Zuhause
#  -Jazz Vibes
#  -Sanfter Pop
#  -Van Life
# Dance/Electronic (15)
#  -Dance Brandneu
#  -Electronic Rising
#  -rave
#  -Techno Bunker
#  -House is a Feeling
#  -Tunnel Vision
#  -Main Stage
#  -Summer Dance Hits 2023
#  -Hardstyle Adrenaline! 2023
#  -Big Room Dance
#  -EDM 2023
#  -DISCOLAND
#  -techno party
#  -Massive Drum & Bass
#  -Hardstyle Remixes
# Rock (15)
#  -Rock Rotation
#  -Rockhymnen
#  -Klare Kante
#  -not just a phase
#  -Alles Rock
#  -angry.wav
#  -Mittelalter Rock
#  -Rock This
#  -ALT NOW
#  -All New Rock
#  -The New Alt
#  -New Noise
#  -The Locker
#  -misfits 2.0
#  -Rock Hard
# Chill (15)
#  -Chillout Lounge
#  -Summer House 2023
#  -Herbst Chillout
#  -Peaceful Piano
#  -lofi beats
#  -Zuhause
#  -Jazz Vibes
#  -Chill Hits
#  -Klavier zum Entspannen
#  -Lowkey Tech
#  -Chill Tracks
#  -Deep House Relax
#  -Jazz in the Background
#  -Comfort Zone
#  -Wochenende
# RADAR (15)
#  -RADAR GSA
#  -RADAR Songwriters
#  -RADAR Global
#  -RADAR US
#  -RADAR Africa
#  -RADAR Nordics
#  -RADAR Korea
#  -RADAR Philippines
#  -RADAR Brasil
#  -RADAR Vietnam
#  -RADAR 新勢力
#  -RADAR: Early Noise
#  -Radar Al Sur
#  -RADAR FRANCE
#  -RADAR Polska
# Fresh Finds (15)
#  -Fresh Finds GSA
#  -Fresh Finds
#  -Fresh Finds Dance
#  -Fresh Finds Indie
#  -Fresh Finds Experimental
#  -Fresh Finds Rock
#  -Fresh Finds Hip-Hop
#  -Fresh Finds R&B
#  -Fresh Finds Pop
#  -Fresh Finds Jazz
#  -Fresh Finds Folk
#  -Fresh Finds Country
#  -Fresh Finds: Class of 2022
#  -Fresh Finds Canada
#  -Fresh Finds Korea
# EQUAL (15)
#  -EQUAL K-Pop
#  -EQUAL - The Players
#  -EQUAL Indie
#  -EQUAL GSA
#  -EQUAL Anime
#  -EQUAL Blues
#  -EQUAL Global
#  -Created by Women
#  -EQUAL New Age
#  -EQUAL Ambient
#  -EQUAL: Classical
#  -EQUAL Indie
#  -Women of Electronic
#  -EQUAL K-Pop
#  -Women of Jazz
# Party (15)
#  -Partyhymnen
#  -Party Deluxe
#  -schiebt anders
#  -90s Dance Party
#  -Throwback Party
#  -Malle Party 2023
#  -Main Stage
#  -NDW – Neue Deutsche Welle
#  -Zurück in die 00er
#  -ملوك السين
#  -ABAT∑RA
#  - شيلات
#  -Fresh Arabic Pop
# Folk & Acoustic (15)
#  -This Is Rodríguez
#  -wanderlust
#  -Your Favorite Coffeehouse
#  -Autumn Acoustic
#  -Wild & Free
#  -Chill Folk
#  -Mountain Air
#  -Soft & Slow
#  -The Wilds
#  -Stay in Bed
#  -Vintage Vibes
#  -longing
#  -Morning Coffee
#  -the new retro
#  -Psych & Groove
# Blues (15)
#  -Nu-Blue
#  -Blues & Roots Rock
#  -Funky Heavy Bluesy
#  -In the Name of the Blues: Marc Broussard Takeover
#  -Modern Blues Rock
#  -Blue Ballads
#  -Modern Blues Guitar
#  -Blues Live & Loud
#  -Blues Roots
#  -Acoustic Grit
#  -Got Blues
#  -Acoustic Blues
#  -Punk Blues
#  -Alt-Blue
#  -Bluestronica
# Word (3)
#  -Spannende Abenteuer
#  -Es war einmal
#  -Learn Arabic

# %%
# list_of_playlist_id = []
# for playlist in top_playlists_by_genre:
#     try: 
#         list_of_playlist_id = list_of_playlist_id + playlist[]

# %%
test = sp.user_playlist_tracks('spotify', '37i9dQZF1DX7ZUug1ANKRP' )

# %%
# all_playlist_ids = []
# for genre in top_playlists_by_genre.values():
#     for playlist in genre:
#         all_playlist_ids.append(playlist['id'])

# %%
all_playlist_ids = [playlist['id'] for genre in top_playlists_by_genre.values() for playlist in genre]
len(all_playlist_ids)
# Out:
# 676

# %%
len(test)

# %%
test["items"][0]["track"].keys()

# %%
from tqdm import tqdm
from time import sleep

def get_all_tracks(playlist_ids):
    all_tracks = []
    for playlist_id in tqdm(playlist_ids):
        tracks = get_tracks_from_playlist(playlist_id)
        all_tracks.extend(tracks)
#         all_tracks.extend([extract_track_info(track) for track in tracks])
    return all_tracks

def get_tracks_from_playlist(playlist_id):
    offset = 0
    tracks = []
    while True:
        response = sp.playlist_tracks(playlist_id, offset=offset)
        tracks.extend(response['items'])
        if response['next'] is None:
            break
        offset += 100
        time.sleep(0.5)
    return tracks

# %%
all_tracks = get_all_tracks(all_playlist_ids)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 676/676 [06:31<00:00,  1.73it/s]

# %%
len(all_tracks)
# Out:
# 73251

# %%
all_tracks
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[197], line 1
# ----> 1 all_tracks
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:268, in DisplayHook.__call__(self, result)
#     266 self.start_displayhook()
#     267 self.write_output_prompt()
# --> 268 format_dict, md_dict = self.compute_format_data(result)
#     269 self.update_user_ns(result)
#     270 self.fill_exec_result(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\displayhook.py:157, in DisplayHook.compute_format_data(self, result)
#     127 def compute_format_data(self, result):
#     128     """Compute format data of the object to be displayed.
#     129
#     130     The format data is a generalization of the :func:`repr` of an object.
#    (...)
#     155
#     156     """
# --> 157     return self.shell.display_formatter.format(result)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:179, in DisplayFormatter.format(self, obj, include, exclude)
#     177 md = None
#     178 try:
# --> 179     data = formatter(obj)
#     180 except:
#     181     # FIXME: log the exception
#     182     raise
#
# File ~\AppData\Roaming\Python\Python310\site-packages\decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:223, in catch_format_error(method, self, *args, **kwargs)
#     221 """show traceback on failed format call"""
#     222 try:
# --> 223     r = method(self, *args, **kwargs)
#     224 except NotImplementedError:
#     225     # don't warn on NotImplementedErrors
#     226     return self._check_return(None, args[0])
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:692, in _dict_pprinter_factory.<locals>.inner(obj, p, cycle)
#     690     p.pretty(key)
#     691     p.text(': ')
# --> 692     p.pretty(obj[key])
#     693 p.end_group(step, end)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:640, in _seq_pprinter_factory.<locals>.inner(obj, p, cycle)
#     638         p.text(',')
#     639         p.breakable()
# --> 640     p.pretty(x)
#     641 if len(obj) == 1 and isinstance(obj, tuple):
#     642     # Special case for 1-item tuples.
#     643     p.text(',')
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:393, in RepresentationPrinter.pretty(self, obj)
#     390 for cls in _get_mro(obj_class):
#     391     if cls in self.type_pprinters:
#     392         # printer registered in self.type_pprinters
# --> 393         return self.type_pprinters[cls](obj, self, cycle)
#     394     else:
#     395         # deferred printer
#     396         printer = self._in_deferred_types(cls)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\lib\pretty.py:782, in _repr_pprint(obj, p, cycle)
#     780 with p.group():
#     781     for idx, output_line in enumerate(lines):
# --> 782         if idx:
#     783             p.break_()
#     784         p.text(output_line)
#
# KeyboardInterrupt:

# %%
def nullTable(dataset):
    round(dataset.isna().sum()/len(dataset),4)*100  # shows the percentage of null values in a column
    nulls_df = pd.DataFrame(round(dataset.isna().sum()/len(dataset),4)*100)
    nulls_df
    nulls_df = nulls_df.reset_index()
    nulls_df
    nulls_df.columns = ['header_name', 'percent_nulls']
    display(nulls_df)
    display(dataset.isna().sum())

# %%
tracks = json_normalize(all_tracks)
len(tracks)
# Out:
# 73251

# %%
tracks.to_pickle('all_tracks_from_top_playlists.pkl')

# %%
nullTable(tracks)

# %%
tracks.dropna(subset='track.artists', inplace = True)

# %%
# tracks = tracks.loc(pd.notna(tracks['track.artists']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_7868\1458796333.py in ?()
# ----> 1 tracks = tracks.loc(pd.notna(tracks['track.artists']))
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in ?(self, axis)
#     664         # we need to return a copy of ourselves
#     665         new_self = type(self)(self.name, self.obj)
#     666
#     667         if axis is not None:
# --> 668             axis = self.obj._get_axis_number(axis)
#     669         new_self.axis = axis
#     670         return new_self
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in ?(cls, axis)
#     551     @classmethod
#     552     def _get_axis_number(cls, axis: Axis) -> int:
#     553         try:
#     554             return cls._AXIS_TO_AXIS_NUMBER[axis]
# --> 555         except KeyError:
#     556             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# TypeError: unhashable type: 'Series'

# %%
nullTable(tracks)
# Out:
#                            header_name  percent_nulls
# 0                             added_at           0.00
# 1                             is_local           0.00
# 2                        primary_color          99.89
# 3       added_by.external_urls.spotify           0.00
# 4                        added_by.href           0.00
# 5                          added_by.id           0.00
# 6                        added_by.type           0.00
# 7                         added_by.uri           0.00
# 8               track.album.album_type           0.00
# 9                  track.album.artists           0.00
# 10       track.album.available_markets           0.00
# 11   track.album.external_urls.spotify           0.00
# 12                    track.album.href           0.00
# 13                      track.album.id           0.00
# 14                  track.album.images           0.00
# 15                    track.album.name           0.00
# 16            track.album.release_date           0.00
# 17  track.album.release_date_precision           0.00
# 18            track.album.total_tracks           0.00
# 19                    track.album.type           0.00
# 20                     track.album.uri           0.00
# 21                       track.artists           0.00
# 22             track.available_markets           0.00
# 23                   track.disc_number           0.00
# 24                   track.duration_ms           0.00
# 25                       track.episode           0.00
# 26                      track.explicit           0.00
# 27             track.external_ids.isrc           0.03
# 28         track.external_urls.spotify           0.00
# 29                          track.href           0.00
# 30                            track.id           0.00
# 31                      track.is_local           0.00
# 32                          track.name           0.00
# 33                    track.popularity           0.00
# 34                   track.preview_url          19.34
# 35                         track.track           0.00
# 36                  track.track_number           0.00
# 37                          track.type           0.00
# 38                           track.uri           0.00
# 39                 video_thumbnail.url         100.00
# 40                               track         100.00
# 41                     video_thumbnail         100.00
# added_at                                  0
# is_local                                  0
# primary_color                         73147
# added_by.external_urls.spotify            0
# added_by.href                             0
# added_by.id                               0
# added_by.type                             0
# added_by.uri                              0
# track.album.album_type                    0
# track.album.artists                       0
# track.album.available_markets             0
# track.album.external_urls.spotify         0
# track.album.href                          0
# track.album.id                            0
# track.album.images                        0
# track.album.name                          0
# track.album.release_date                  0
# track.album.release_date_precision        0
# track.album.total_tracks                  0
# track.album.type                          0
# track.album.uri                           0
# track.artists                             0
# track.available_markets                   0
# track.disc_number                         0
# track.duration_ms                         0
# track.episode                             0
# track.explicit                            0
# track.external_ids.isrc                  20
# track.external_urls.spotify               0
# track.href                                0
# track.id                                  0
# track.is_local                            0
# track.name                                0
# track.popularity                          0
# track.preview_url                     14164
# track.track                               0
# track.track_number                        0
# track.type                                0
# track.uri                                 0
# video_thumbnail.url                   73224
# track                                 73224
# video_thumbnail                       73224
# dtype: int64

# %%
def list_to_dict(x):
    return {i: x[i] for i in range(len(x))}

# %%
tracks['artist_dict'] = tracks['track.artists'].apply(list_to_dict)

# %%
tracks['track.id']
# Out:
# 0        31nfdEooLEq7dn3UMcIeB5
# 1        0gMTEHzNIyvxikxyUFFJxO
# 2        2IGMVunIBsBLtEQyoI1Mu7
# 3        5YWu6dt50Nieq8qi572RF8
# 4        59NraMJsLaMCVtwXTSia8i
#                   ...
# 73246    1XQ8bXmDNU7VD4IvAsq6my
# 73247    5O15B1osF9aPtpU2sQvkqB
# 73248    4KL1ztWsn27X4yFWmpaS9t
# 73249    5ymvXhdhvCpu1c6vIoKrBr
# 73250    14RTzCzFizaOdDgxfUsPs2
# Name: track.id, Length: 73224, dtype: object

# %%
tracks.columns
# Out:
# Index(['added_at', 'is_local', 'primary_color',
#        'added_by.external_urls.spotify', 'added_by.href', 'added_by.id',
#        'added_by.type', 'added_by.uri', 'track.album.album_type',
#        'track.album.artists', 'track.album.available_markets',
#        'track.album.external_urls.spotify', 'track.album.href',
#        'track.album.id', 'track.album.images', 'track.album.name',
#        'track.album.release_date', 'track.album.release_date_precision',
#        'track.album.total_tracks', 'track.album.type', 'track.album.uri',
#        'track.artists', 'track.available_markets', 'track.disc_number',
#        'track.duration_ms', 'track.episode', 'track.explicit',
#        'track.external_ids.isrc', 'track.external_urls.spotify', 'track.href',
#        'track.id', 'track.is_local', 'track.name', 'track.popularity',
#        'track.preview_url', 'track.track', 'track.track_number', 'track.type',
#        'track.uri', 'video_thumbnail.url', 'track', 'video_thumbnail',
#        'artist_dict'],
#       dtype='object')

# %%
chunks = [(i, i+100) for i in range(0, len(tracks), 100)]
audio_features_list = []
for chunk in tqdm(chunks):
    id_list100 = tracks['track.id'][chunk[0]:chunk[1]]
    audio_features_list = audio_features_list + sp.audio_features(id_list100)
    sleep(randint(1,3000)/1000)
len(audio_features_list)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 733/733 [20:42<00:00,  1.69s/it]
# 73224

# %%
audio_feature_df = json_normalize(audio_features_list )

# %%
audio_feature_df
# Out:
#        danceability  energy   key  loudness  mode  speechiness  acousticness  \
# 0             0.634   0.824   2.0    -3.394   0.0       0.0470        0.0908
# 1             0.756   0.647   6.0    -5.488   0.0       0.1590        0.2790
# 2             0.868   0.538   5.0    -8.603   1.0       0.1740        0.2690
# 3             0.767   0.539   4.0    -8.518   0.0       0.0629        0.3640
# 4             0.638   0.717   8.0    -5.804   1.0       0.0375        0.0010
# ...             ...     ...   ...       ...   ...          ...           ...
# 73219         0.633   0.759   0.0   -11.833   1.0       0.0368        0.1220
# 73220         0.830   0.759   0.0   -11.880   1.0       0.0315        0.2140
# 73221         0.811   0.603   7.0   -12.997   1.0       0.0649        0.5420
# 73222         0.819   0.222   9.0   -15.183   0.0       0.0397        0.3490
# 73223         0.762   0.448  11.0   -13.840   0.0       0.1650        0.0716
#
#        instrumentalness  liveness  valence    tempo            type  \
# 0              0.071100    0.1190    0.371  137.959  audio_features
# 1              0.000005    0.1020    0.464  134.995  audio_features
# 2              0.000003    0.0901    0.732   99.968  audio_features
# 3              0.039700    0.0772    0.368  128.055  audio_features
# 4              0.000002    0.1130    0.422  141.904  audio_features
# ...                 ...       ...      ...      ...             ...
# 73219          0.424000    0.1320    0.926  110.034  audio_features
# 73220          0.876000    0.1150    0.955  125.009  audio_features
# 73221          0.925000    0.0911    0.725  110.014  audio_features
# 73222          0.112000    0.1080    0.791  137.286  audio_features
# 73223          0.822000    0.0872    0.968   95.007  audio_features
#
#                            id                                   uri  \
# 0      31nfdEooLEq7dn3UMcIeB5  spotify:track:31nfdEooLEq7dn3UMcIeB5
# 1      0gMTEHzNIyvxikxyUFFJxO  spotify:track:0gMTEHzNIyvxikxyUFFJxO
# 2      2IGMVunIBsBLtEQyoI1Mu7  spotify:track:2IGMVunIBsBLtEQyoI1Mu7
# 3      5YWu6dt50Nieq8qi572RF8  spotify:track:5YWu6dt50Nieq8qi572RF8
# 4      59NraMJsLaMCVtwXTSia8i  spotify:track:59NraMJsLaMCVtwXTSia8i
# ...                       ...                                   ...
# 73219  1XQ8bXmDNU7VD4IvAsq6my  spotify:track:1XQ8bXmDNU7VD4IvAsq6my
# 73220  5O15B1osF9aPtpU2sQvkqB  spotify:track:5O15B1osF9aPtpU2sQvkqB
# 73221  4KL1ztWsn27X4yFWmpaS9t  spotify:track:4KL1ztWsn27X4yFWmpaS9t
# 73222  5ymvXhdhvCpu1c6vIoKrBr  spotify:track:5ymvXhdhvCpu1c6vIoKrBr
# 73223  14RTzCzFizaOdDgxfUsPs2  spotify:track:14RTzCzFizaOdDgxfUsPs2
#
#                                               track_href  \
# 0      https://api.spotify.com/v1/tracks/31nfdEooLEq7...
# 1      https://api.spotify.com/v1/tracks/0gMTEHzNIyvx...
# 2      https://api.spotify.com/v1/tracks/2IGMVunIBsBL...
# 3      https://api.spotify.com/v1/tracks/5YWu6dt50Nie...
# 4      https://api.spotify.com/v1/tracks/59NraMJsLaMC...
# ...                                                  ...
# 73219  https://api.spotify.com/v1/tracks/1XQ8bXmDNU7V...
# 73220  https://api.spotify.com/v1/tracks/5O15B1osF9aP...
# 73221  https://api.spotify.com/v1/tracks/4KL1ztWsn27X...
# 73222  https://api.spotify.com/v1/tracks/5ymvXhdhvCpu...
# 73223  https://api.spotify.com/v1/tracks/14RTzCzFizaO...
#
#                                             analysis_url  duration_ms  \
# 0      https://api.spotify.com/v1/audio-analysis/31nf...     178156.0
# 1      https://api.spotify.com/v1/audio-analysis/0gMT...     195466.0
# 2      https://api.spotify.com/v1/audio-analysis/2IGM...     231750.0
# 3      https://api.spotify.com/v1/audio-analysis/5YWu...     131524.0
# 4      https://api.spotify.com/v1/audio-analysis/59Nr...     132359.0
# ...                                                  ...          ...
# 73219  https://api.spotify.com/v1/audio-analysis/1XQ8...     163533.0
# 73220  https://api.spotify.com/v1/audio-analysis/5O15...     177133.0
# 73221  https://api.spotify.com/v1/audio-analysis/4KL1...     153453.0
# 73222  https://api.spotify.com/v1/audio-analysis/5ymv...     134200.0
# 73223  https://api.spotify.com/v1/audio-analysis/14RT...     193453.0
#
#        time_signature
# 0                 4.0
# 1                 4.0
# 2                 4.0
# 3                 4.0
# 4                 4.0
# ...               ...
# 73219             4.0
# 73220             4.0
# 73221             4.0
# 73222             4.0
# 73223             4.0
#
# [73224 rows x 18 columns]

# %%
audio_feature_df.to_pickle('audio_feature_df.pkl')
